# %% [markdown]
# # Context ✒️
#
# Notebook destinado ao estudo e implementação de IA's generaticas Open Source, com a plataforma Hugginng Face, que de forma simples e direta é um repositório de modelos de IA e machine learning.
#
# O objetivo desse notebook é servir de introdução ao Hugging Face, implementando no processo alguns modelos atrelados a certas atividades, tais como compreensão de fala, classificação de imagens e etc.
#
# English :
#
# Notebook intended for the study and implementation of Open Source generative AI, with the Hugginng Face platform, which in a simple and direct way is a repository of AI and machine learning models.
#
# The objective of this notebook is to serve as an introduction to Hugging Face, implementing in the process some models linked to certain activities, such as speech understanding, image classification, etc.

# %% [markdown]
# ## Librarys 📚

# %%
# !pip install transformers -q

# %%
import torch

from transformers import pipeline
from transformers import Conversation

from transformers.utils import logging
logging.set_verbosity_error()

# %% [markdown]
# ## Tradutor

# %%
translator = pipeline(task="translation",
                      model="facebook/nllb-200-distilled-600M",
                      torch_dtype=torch.bfloat16)
# Out:
# config.json:   0%|          | 0.00/846 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.46G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/564 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/4.85M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/3.55k [00:00<?, ?B/s]

# %%
text = """\
My puppy is adorable, \
Your kitten is cute.
Her panda is friendly.
His llama is thoughtful. \
We all have nice pets!
"""

# %%
text_translated = translator(text,
                             src_lang="eng_Latn",
                             tgt_lang="por_Latn")

# %%
text_translated
# Out:
# [{'translation_text': 'O meu cachorro é adorável, o seu gatinho é giro, o seu panda é amigável, o seu lama é atencioso, todos nós temos bons animais de estimação.'}]

# %% [markdown]
# ## Sumarizador

# %%
# Liberando memória para realizar os processos seguintes

import gc

del translator

gc.collect()
# Out:
# 149

# %%
summarizer = pipeline(task="summarization",
                      model="facebook/bart-large-cnn",
                      torch_dtype=torch.bfloat16)
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
text = """Paris is the capital and most populous city of France, with
          an estimated population of 2,175,601 residents as of 2018,
          in an area of more than 105 square kilometres (41 square
          miles). The City of Paris is the centre and seat of
          government of the region and province of Île-de-France, or
          Paris Region, which has an estimated population of
          12,174,880, or about 18 percent of the population of France
          as of 2017."""

# %%
summary = summarizer(text,
                     min_length=10,
                     max_length=100)

# %%
summary
# Out:
# [{'summary_text': 'Paris is the capital and most populous city of France, with an estimated population of 2,175,601 residents as of 2018. The City of Paris is the centre and seat of the government of the region and province of Île-de-France.'}]
